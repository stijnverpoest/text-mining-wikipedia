# %%
- ga over alle mapjes in een map (niet recursief) en geef de mapnamen

- voor elke mapnaam: ga nog is over alle files in die map (dus "map/...") En laadt deze in met onderstaande query

    
from os import listdir
bestanden = listdir("map")
for bestand in bestanden:
    
    os.walk
if bestand.startswith("myoutput"):
    filenames = listdir("map")
for filename in filenames:
  if filename.startswith("part"):
      with open (mapname + "/" + filename) as file:

# %%
import pandas as pd

def lees(waarde):
    import json
    with open (waarde) as json_file:
        print(json_file) #to spot mistakes
        data = json.load(json_file)
    df = pd.DataFrame()
    df = df.append(data, ignore_index=True)

# %%
from os import listdir

rootdir = r"C:\Users\Stijn\Desktop\spark"

for subdir, dirs, files in os.walk(rootdir):
    for filename in files:
        if filename.startswith("part-00"):
            filepath = subdir + os.sep + filename
            lees(filepath)
        else:
            continue
# Out:
# <_io.TextIOWrapper name='C:\\Users\\Stijn\\Desktop\\spark\\myoutput-1587679230000\\part-00000' mode='r' encoding='cp1252'>
# <_io.TextIOWrapper name='C:\\Users\\Stijn\\Desktop\\spark\\myoutput-1587679230000\\part-00001' mode='r' encoding='cp1252'>
# <_io.TextIOWrapper name='C:\\Users\\Stijn\\Desktop\\spark\\myoutput-1587679240000\\part-00000' mode='r' encoding='cp1252'>
# <_io.TextIOWrapper name='C:\\Users\\Stijn\\Desktop\\spark\\myoutput-1587679240000\\part-00001' mode='r' encoding='cp1252'>
# <_io.TextIOWrapper name='C:\\Users\\Stijn\\Desktop\\spark\\myoutput-1587679240000\\part-00002' mode='r' encoding='cp1252'>
# <_io.TextIOWrapper name='C:\\Users\\Stijn\\Desktop\\spark\\myoutput-1587679250000\\part-00000' mode='r' encoding='cp1252'>
# <_io.TextIOWrapper name='C:\\Users\\Stijn\\Desktop\\spark\\myoutput-1587679250000\\part-00001' mode='r' encoding='cp1252'>
# <_io.TextIOWrapper name='C:\\Users\\Stijn\\Desktop\\spark\\myoutput-1587679260000\\part-00000' mode='r' encoding='cp1252'>
# ...

# %%
import os
rootdir = r"C:\Users\Stijn\Desktop\spark"

for subdir, dirs, files in os.walk(rootdir):
    for file in files:
        print (os.path.join(subdir, file))
# Out:
# C:\Users\Stijn\Desktop\spark\letsgo-mac.sh
# C:\Users\Stijn\Desktop\spark\letsgo-win.bat
# C:\Users\Stijn\Desktop\spark\Make dataframe.ipynb
# C:\Users\Stijn\Desktop\spark\Make dataframe1.ipynb
# C:\Users\Stijn\Desktop\spark\part-00000
# C:\Users\Stijn\Desktop\spark\.ipynb_checkpoints\Make dataframe-checkpoint.ipynb
# C:\Users\Stijn\Desktop\spark\.ipynb_checkpoints\Make dataframe1-checkpoint.ipynb
# C:\Users\Stijn\Desktop\spark\jre1.8.0_241\COPYRIGHT
# C:\Users\Stijn\Desktop\spark\jre1.8.0_241\LICENSE
# C:\Users\Stijn\Desktop\spark\jre1.8.0_241\README.txt
# C:\Users\Stijn\Desktop\spark\jre1.8.0_241\release
# C:\Users\Stijn\Desktop\spark\jre1.8.0_241\THIRDPARTYLICENSEREADME-JAVAFX.txt
# C:\Users\Stijn\Desktop\spark\jre1.8.0_241\THIRDPARTYLICENSEREADME.txt
# C:\Users\Stijn\Desktop\spark\jre1.8.0_241\Welcome.html
# C:\Users\Stijn\Desktop\spark\jre1.8.0_241\bin\api-ms-win-core-console-l1-1-0.dll
# C:\Users\Stijn\Desktop\spark\jre1.8.0_241\bin\api-ms-win-core-datetime-l1-1-0.dll
# ...

# %%
def lees(waarde):
    import json
    with open (waarde) as json_file:
        data = json.load(json_file)
    df = pd.DataFrame()
    df = df.append(data, ignore_index=True)

# %%
from os import listdir

#files = listdir(r"C:\Users\Stijn\Desktop\spark")
rootdir = r"C:\Users\Stijn\Desktop\spark"

for subdir, dirs, files in os.walk(rootdir):
    for filename in files:
        filepath = subdir + os.sep + filename
        print(filename)
# Out:
# letsgo-mac.sh
# letsgo-win.bat
# Make dataframe.ipynb
# Make dataframe1.ipynb
# part-00000
# Make dataframe-checkpoint.ipynb
# Make dataframe1-checkpoint.ipynb
# COPYRIGHT
# LICENSE
# README.txt
# release
# THIRDPARTYLICENSEREADME-JAVAFX.txt
# THIRDPARTYLICENSEREADME.txt
# Welcome.html
# api-ms-win-core-console-l1-1-0.dll
# api-ms-win-core-datetime-l1-1-0.dll
# api-ms-win-core-debug-l1-1-0.dll
# api-ms-win-core-errorhandling-l1-1-0.dll
# api-ms-win-core-file-l1-1-0.dll
# api-ms-win-core-file-l1-2-0.dll
# api-ms-win-core-file-l2-1-0.dll
# api-ms-win-core-handle-l1-1-0.dll
# api-ms-win-core-heap-l1-1-0.dll
# api-ms-win-core-interlocked-l1-1-0.dll
# api-ms-win-core-libraryloader-l1-1-0.dll
# api-ms-win-core-localization-l1-2-0.dll
# api-ms-win-core-memory-l1-1-0.dll
# api-ms-win-core-namedpipe-l1-1-0.dll
# api-ms-win-core-processenvironment-l1-1-0.dll
# api-ms-win-core-processthreads-l1-1-0.dll
# api-ms-win-core-processthreads-l1-1-1.dll
# api-ms-win-core-profile-l1-1-0.dll
# ...

# %%
if bestanden.startswith("myoutput"):
    filenames = listdir(r"C:\Users\Stijn\Desktop\spark")
for filename in filenames:
    if filename.startswith("part"):
        with open (r"C:\Users\Stijn\Desktop\spark" + "/" + filename) as file:

# %%
import json

with open('part-00000') as json_file:
    data = json.load(json_file)

# %%
import pandas as pd
df = pd.DataFrame()
print (df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df = df.append(data, ignore_index=True)

# %%
df.head()
# Out:
#                                   comment label               name_user  \
# 0  →‎External links:add authority control  safe  Ser Amantio di Nicolao
#
#                                             text_new  \
# 0  '''Covenant Health''' is the largest Catholic ...
#
#                                             text_old  \
# 0  '''Covenant Health''' is the largest Catholic ...
#
#                   title_page  \
# 0  Covenant Health (Alberta)
#
#                                             url_page
# 0  //en.wikipedia.org/wiki/Covenant_Health_(Alberta)
