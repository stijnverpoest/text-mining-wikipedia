# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
from threading import Thread

class StreamingThread(Thread):
    def __init__(self, ssc):
        Thread.__init__(self)
        self.ssc = ssc
    def run(self):
        ssc.start()
        ssc.awaitTermination()
    def stop(self):
        print('----- Stopping... this may take a few seconds -----')
        self.ssc.stop(stopSparkContext=False, stopGraceFully=True)

# %%
sc
# Out:
# <SparkContext master=local[*] appName=PySparkShell>

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.0.229:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.4.5</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
from pyspark.streaming import StreamingContext
from pyspark.sql import Row
from pyspark.sql.functions import udf, struct, array, col, lit
from pyspark.sql.types import StringType

# %%
from difflib import unified_diff

def make_diff(old, new):
    return '\n'.join([ l for l in unified_diff(old.split('\n'), new.split('\n')) if l.startswith('+') or l.startswith('-') ])

# %%
globals()['models_loaded'] = False

def predict(df):
    if any([x in df.diff.lower() for x in ['bad', 'lol', 'joke']]):
        return 'vandal'
    else:
        return 'safe'

predict_udf = udf(predict, StringType())

def process(time, rdd):
    if rdd.isEmpty():
        return
    
    print("========= %s =========" % str(time))
    
    # Convert to data frame
    df = spark.read.json(rdd)
    df.show()
    
    # Tip: making a diff will probably help a lot as a feature in any model:
    diff = make_diff(df.first().text_old, df.first().text_new)
    df_withdiff = df.withColumn("diff", lit(diff))
    df_withdiff.select('diff').show()
    
    # Utilize our predict function
    df_withpreds = df_withdiff.withColumn("pred", predict_udf(
        struct([df_withdiff[x] for x in df_withdiff.columns])
    ))
    df_withpreds.show()
    
    # Normally, you wouldn't use a UDF (User Defined Function) Python function to predict (you can)
    # But an MLlib model you've built and saved with Spark
    # In this case, you need to prevent loading your model in every call to "process" as follows:
    
    # Load in the model if not yet loaded:
    if not globals()['models_loaded']:
        # load in your models here
        globals()['my_model'] = '***' # Replace '***' with:    [...].load('my_logistic_regression')
        globals()['models_loaded'] = True
        
    # And then predict using the loaded model: 
    # df_result = globals()['my_model'].transform(df)
    # df_result.show()

# %%
ssc = StreamingContext(sc, 10)

# %%
lines = ssc.socketTextStream("seppe.net", 7778)
lines.foreachRDD(process)

# %%
ssc_t = StreamingThread(ssc)
ssc_t.start()
# Out:
# ========= 2020-04-24 01:01:40 =========
# +--------------------+------+--------------+--------------------+--------------------+--------------------+--------------------+
# |             comment| label|     name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+------+--------------+--------------------+--------------------+--------------------+--------------------+
# |Adding localshort...|  safe|  Red Director|{{short descripti...|{{Other people|Al...|Alan Jones (footb...|//en.wikipedia.or...|
# |(→‎Royal Warrant:...|unsafe|213.205.200.10|{{refimprove|date...|{{refimprove|date...|    Turnbull & Asser|//en.wikipedia.or...|
# |→‎Credits and per...|  safe|Thedivinemania|{{Infobox album
# |...|{{Infobox album
# |...|Afterburner (Danc...|//en.wikipedia.or...|
# |→‎External links:...|  safe|      Yarnalgo|{{short descripti...|{{short descripti...|            Starlink|//en.wikipedia.or...|
# |→‎Sudler Trophy:F...|  safe|   Shonebrooks|{{infobox organiz...|{{infobox organiz...|John Philip Sousa...|//en.wikipedia.or...|
# +--------------------+------+--------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# +{{sh...|
# |---
#
# +++
#
# +{{sh...|
# |---
#
# +++
#
# +{{sh...|
# |---
#
# +++
#
# +{{sh...|
# |---
#
# +++
#
# +{{sh...|
# +--------------------+
#
# +--------------------+------+--------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |             comment| label|     name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +--------------------+------+--------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |Adding localshort...|  safe|  Red Director|{{short descripti...|{{Other people|Al...|Alan Jones (footb...|//en.wikipedia.or...|---
#
# +++
#
# +{{sh...|safe|
# |(→‎Royal Warrant:...|unsafe|213.205.200.10|{{refimprove|date...|{{refimprove|date...|    Turnbull & Asser|//en.wikipedia.or...|---
#
# +++
#
# +{{sh...|safe|
# |→‎Credits and per...|  safe|Thedivinemania|{{Infobox album
# |...|{{Infobox album
# |...|Afterburner (Danc...|//en.wikipedia.or...|---
#
# +++
#
# +{{sh...|safe|
# |→‎External links:...|  safe|      Yarnalgo|{{short descripti...|{{short descripti...|            Starlink|//en.wikipedia.or...|---
#
# +++
#
# +{{sh...|safe|
# |→‎Sudler Trophy:F...|  safe|   Shonebrooks|{{infobox organiz...|{{infobox organiz...|John Philip Sousa...|//en.wikipedia.or...|---
#
# +++
#
# +{{sh...|safe|
# +--------------------+------+--------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
#
# ========= 2020-04-24 01:01:50 =========
# +--------------------+------+-------------+--------------------+--------------------+--------------------+--------------------+
# |             comment| label|    name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+------+-------------+--------------------+--------------------+--------------------+--------------------+
# |           (Content)|unsafe| 80.5.242.133|{{Use British Eng...|{{Use British Eng...|  Gabriel Agbonlahor|//en.wikipedia.or...|
# |                    |unsafe|66.108.230.93|{{Use mdy dates|d...|{{Use mdy dates|d...|Daniel Lewis (con...|//en.wikipedia.or...|
# |→‎Painting:Added ...|  safe|   Lrayshel23|{{Use American En...|{{Use American En...|California Colleg...|//en.wikipedia.or...|
# |Adding localshort...|  safe| Red Director|{{short descripti...|{{Use dmy dates|d...|Dale Williams (fo...|//en.wikipedia.or...|
# +--------------------+------+-------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# -| po...|
# |---
#
# +++
#
# -| po...|
# |---
#
# +++
#
# -| po...|
# |---
#
# +++
#
# -| po...|
# +--------------------+
#
# +--------------------+------+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |             comment| label|    name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +--------------------+------+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |           (Content)|unsafe| 80.5.242.133|{{Use British Eng...|{{Use British Eng...|  Gabriel Agbonlahor|//en.wikipedia.or...|---
#
# +++
#
# -| po...|safe|
# |                    |unsafe|66.108.230.93|{{Use mdy dates|d...|{{Use mdy dates|d...|Daniel Lewis (con...|//en.wikipedia.or...|---
#
# +++
#
# -| po...|safe|
# |→‎Painting:Added ...|  safe|   Lrayshel23|{{Use American En...|{{Use American En...|California Colleg...|//en.wikipedia.or...|---
#
# +++
#
# -| po...|safe|
# |Adding localshort...|  safe| Red Director|{{short descripti...|{{Use dmy dates|d...|Dale Williams (fo...|//en.wikipedia.or...|---
#
# +++
#
# -| po...|safe|
# +--------------------+------+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
#
# ========= 2020-04-24 01:02:00 =========
# +--------------------+-----+-----------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|  name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+-----------+--------------------+--------------------+--------------------+--------------------+
# |rm incorrect dock...| safe|     RA0808|{{Unreferenced|da...|{{Unreferenced|da...|Munro v National ...|//en.wikipedia.or...|
# |  It links to itself| safe|Yujie.ho123|{{Multiple issues...|{{Multiple issues...|  Miles Sound System|//en.wikipedia.or...|
# +--------------------+-----+-----------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# -  |d...|
# |---
#
# +++
#
# -  |d...|
# +--------------------+
#
# +--------------------+-----+-----------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |             comment|label|  name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +--------------------+-----+-----------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |rm incorrect dock...| safe|     RA0808|{{Unreferenced|da...|{{Unreferenced|da...|Munro v National ...|//en.wikipedia.or...|---
#
# +++
#
# -  |d...|safe|
# |  It links to itself| safe|Yujie.ho123|{{Multiple issues...|{{Multiple issues...|  Miles Sound System|//en.wikipedia.or...|---
#
# +++
#
# -  |d...|safe|
# +--------------------+-----+-----------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
#
# ========= 2020-04-24 01:02:10 =========
# +--------------------+------+-------------+--------------------+--------------------+--------------------+--------------------+
# |             comment| label|    name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+------+-------------+--------------------+--------------------+--------------------+--------------------+
# |Adding localshort...|  safe| Red Director|{{short descripti...|{{other people}}
# ...|          Bert Evans|//en.wikipedia.or...|
# |   miscapitalization|  safe|      Wbm1058|{{Use mdy dates|d...|{{Use mdy dates|d...|     Jack Kent Cooke|//en.wikipedia.or...|
# |                    |unsafe|136.35.32.140|{{Use mdy dates|d...|{{Use mdy dates|d...|The Amityville Ho...|//en.wikipedia.or...|
# |Adding localshort...|  safe| Red Director|{{short descripti...|{{Use dmy dates|d...|John Jarman (foot...|//en.wikipedia.or...|
# +--------------------+------+-------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# +{{sh...|
# |---
#
# +++
#
# +{{sh...|
# |---
#
# +++
#
# +{{sh...|
# |---
#
# +++
#
# +{{sh...|
# +--------------------+
# +--------------------+------+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |             comment| label|    name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +--------------------+------+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |Adding localshort...|  safe| Red Director|{{short descripti...|{{other people}}
# ...|          Bert Evans|//en.wikipedia.or...|---
#
# +++
#
# +{{sh...|safe|
# |   miscapitalization|  safe|      Wbm1058|{{Use mdy dates|d...|{{Use mdy dates|d...|     Jack Kent Cooke|//en.wikipedia.or...|---
#
# +++
#
# +{{sh...|safe|
# |                    |unsafe|136.35.32.140|{{Use mdy dates|d...|{{Use mdy dates|d...|The Amityville Ho...|//en.wikipedia.or...|---
#
# +++
#
# +{{sh...|safe|
# |Adding localshort...|  safe| Red Director|{{short descripti...|{{Use dmy dates|d...|John Jarman (foot...|//en.wikipedia.or...|---
#
# +++
#
# +{{sh...|safe|
# +--------------------+------+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
#
# ========= 2020-04-24 01:02:20 =========
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|   name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
# |Addingshort descr...| safe|Red Director|{{short descripti...|{{Use British Eng...|Roger Ashton (foo...|//en.wikipedia.or...|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# +{{sh...|
# +--------------------+
#
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |             comment|label|   name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |Addingshort descr...| safe|Red Director|{{short descripti...|{{Use British Eng...|Roger Ashton (foo...|//en.wikipedia.or...|---
#
# +++
#
# +{{sh...|safe|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
#
# ========= 2020-04-24 01:02:30 =========
# +--------------------+-----+---------------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|      name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+---------------+--------------------+--------------------+--------------------+--------------------+
# |Adding localshort...| safe|   Red Director|{{short descripti...|{{Infobox footbal...|Terry Taylor (foo...|//en.wikipedia.or...|
# |Added citation fo...| safe|Doctor S Monkey|[[File:Matilda El...|[[File:Matilda El...|Matilda Ellen Bishop|//en.wikipedia.or...|
# |→‎Corporate Infor...| safe|        EdmundT|{{Use Indian Engl...|{{Use Indian Engl...|   Navneet Education|//en.wikipedia.or...|
# +--------------------+-----+---------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# +{{sh...|
# |---
#
# +++
#
# +{{sh...|
# |---
#
# +++
#
# +{{sh...|
# +--------------------+
#
# +--------------------+-----+---------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |             comment|label|      name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +--------------------+-----+---------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |Adding localshort...| safe|   Red Director|{{short descripti...|{{Infobox footbal...|Terry Taylor (foo...|//en.wikipedia.or...|---
#
# +++
#
# +{{sh...|safe|
# |Added citation fo...| safe|Doctor S Monkey|[[File:Matilda El...|[[File:Matilda El...|Matilda Ellen Bishop|//en.wikipedia.or...|---
#
# +++
#
# +{{sh...|safe|
# |→‎Corporate Infor...| safe|        EdmundT|{{Use Indian Engl...|{{Use Indian Engl...|   Navneet Education|//en.wikipedia.or...|---
#
# +++
#
# +{{sh...|safe|
# +--------------------+-----+---------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
#
# ========= 2020-04-24 01:02:40 =========
# +--------------------+------+--------------+--------------------+--------------------+--------------------+--------------------+
# |             comment| label|     name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+------+--------------+--------------------+--------------------+--------------------+--------------------+
# |Adding localshort...|  safe|  Red Director|{{short descripti...|{{Use British Eng...|Billy Richards (f...|//en.wikipedia.or...|
# |Updated infobox (...|  safe|         Wolbo|{{short descripti...|{{short descripti...|     Percival Davson|//en.wikipedia.or...|
# |(→‎Red-brown (web...|unsafe|207.189.162.81|{{pp-pc1}}
# {{info...|{{pp-pc1}}
# {{info...|     Shades of brown|//en.wikipedia.or...|
# +--------------------+------+--------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# +{{sh...|
# |---
#
# +++
#
# +{{sh...|
# |---
#
# +++
#
# +{{sh...|
# +--------------------+
#
# +--------------------+------+--------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |             comment| label|     name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +--------------------+------+--------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |Adding localshort...|  safe|  Red Director|{{short descripti...|{{Use British Eng...|Billy Richards (f...|//en.wikipedia.or...|---
#
# +++
#
# +{{sh...|safe|
# |Updated infobox (...|  safe|         Wolbo|{{short descripti...|{{short descripti...|     Percival Davson|//en.wikipedia.or...|---
#
# +++
#
# +{{sh...|safe|
# |(→‎Red-brown (web...|unsafe|207.189.162.81|{{pp-pc1}}
# {{info...|{{pp-pc1}}
# {{info...|     Shades of brown|//en.wikipedia.or...|---
#
# +++
#
# +{{sh...|safe|
# +--------------------+------+--------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
#
# ========= 2020-04-24 01:02:50 =========
# +--------------------+-----+----------------+--------------------+--------------------+-------------------+--------------------+
# |             comment|label|       name_user|            text_new|            text_old|         title_page|            url_page|
# +--------------------+-----+----------------+--------------------+--------------------+-------------------+--------------------+
# |Adding localshort...| safe|    Red Director|{{short descripti...|{{Use dmy dates|d...|    Byron Stevenson|//en.wikipedia.or...|
# |Adding localshort...| safe|    Red Director|{{short descripti...|{{about|Samuel Me...|       Sam Meredith|//en.wikipedia.or...|
# |copy edit without...| safe|LauraBradleyMoss|[[File:William He...|[[File:William He...|Curse of Tippecanoe|//en.wikipedia.or...|
# +--------------------+-----+----------------+--------------------+--------------------+-------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# +{{sh...|
# |---
#
# +++
#
# +{{sh...|
# |---
#
# +++
#
# +{{sh...|
# +--------------------+
# +--------------------+-----+----------------+--------------------+--------------------+-------------------+--------------------+--------------------+----+
# |             comment|label|       name_user|            text_new|            text_old|         title_page|            url_page|                diff|pred|
# +--------------------+-----+----------------+--------------------+--------------------+-------------------+--------------------+--------------------+----+
# |Adding localshort...| safe|    Red Director|{{short descripti...|{{Use dmy dates|d...|    Byron Stevenson|//en.wikipedia.or...|---
#
# +++
#
# +{{sh...|safe|
# |Adding localshort...| safe|    Red Director|{{short descripti...|{{about|Samuel Me...|       Sam Meredith|//en.wikipedia.or...|---
#
# +++
#
# +{{sh...|safe|
# |copy edit without...| safe|LauraBradleyMoss|[[File:William He...|[[File:William He...|Curse of Tippecanoe|//en.wikipedia.or...|---
#
# +++
#
# +{{sh...|safe|
# +--------------------+-----+----------------+--------------------+--------------------+-------------------+--------------------+--------------------+----+
#
# ========= 2020-04-24 01:03:00 =========
# +--------------------+-----+---------------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|      name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+---------------+--------------------+--------------------+--------------------+--------------------+
# |→‎Development and...| safe|         KGRAMR|{{Infobox video g...|{{Infobox video g...|          Truxton II|//en.wikipedia.or...|
# |         Added links| safe|Joshuadejohnson|{{Infobox album
# |...|{{Infobox album
# |...|Don't Get Comfort...|//en.wikipedia.or...|
# | →‎22 April:Spelling| safe|        EdmundT|{{short descripti...|{{short descripti...|Timeline of the 2...|//en.wikipedia.or...|
# |edited literacy rate| safe|  Kingarthur581|{{unreferenced|da...|{{unreferenced|da...|            Garbalia|//en.wikipedia.or...|
# +--------------------+-----+---------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# -On A...|
# |---
#
# +++
#
# -On A...|
# |---
#
# +++
#
# -On A...|
# |---
#
# +++
#
# -On A...|
# +--------------------+
#
# +--------------------+-----+---------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |             comment|label|      name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +--------------------+-----+---------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |→‎Development and...| safe|         KGRAMR|{{Infobox video g...|{{Infobox video g...|          Truxton II|//en.wikipedia.or...|---
#
# +++
#
# -On A...|safe|
# |         Added links| safe|Joshuadejohnson|{{Infobox album
# |...|{{Infobox album
# |...|Don't Get Comfort...|//en.wikipedia.or...|---
#
# +++
#
# -On A...|safe|
# | →‎22 April:Spelling| safe|        EdmundT|{{short descripti...|{{short descripti...|Timeline of the 2...|//en.wikipedia.or...|---
#
# +++
#
# -On A...|safe|
# |edited literacy rate| safe|  Kingarthur581|{{unreferenced|da...|{{unreferenced|da...|            Garbalia|//en.wikipedia.or...|---
#
# +++
#
# -On A...|safe|
# +--------------------+-----+---------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
#
# ========= 2020-04-24 01:03:10 =========
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|    name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+
# |      →‎top:clean up| safe|    WolfmanSF|{{speciesbox
# | na...|{{speciesbox
# | na...|Rusty-fronted can...|//en.wikipedia.or...|
# |Sanskrit - Nomina...| safe|Naveen Sankar|{{pp-pc1}}
# {{shor...|{{pp-pc1}}
# {{shor...|            Sanskrit|//en.wikipedia.or...|
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# -The ...|
# |---
#
# +++
#
# -The ...|
# +--------------------+
#
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |             comment|label|    name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |      →‎top:clean up| safe|    WolfmanSF|{{speciesbox
# | na...|{{speciesbox
# | na...|Rusty-fronted can...|//en.wikipedia.or...|---
#
# +++
#
# -The ...|safe|
# |Sanskrit - Nomina...| safe|Naveen Sankar|{{pp-pc1}}
# {{shor...|{{pp-pc1}}
# {{shor...|            Sanskrit|//en.wikipedia.or...|---
#
# +++
#
# -The ...|safe|
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
#
# ========= 2020-04-24 01:03:20 =========
# +--------------------+------+-----------------+--------------------+--------------------+--------------+--------------------+
# |             comment| label|        name_user|            text_new|            text_old|    title_page|            url_page|
# +--------------------+------+-----------------+--------------------+--------------------+--------------+--------------------+
# |      →‎Origins:trim|  safe|         Eebahgum|{{EngvarB|date=Se...|{{EngvarB|date=Se...|Fulk FitzWarin|//en.wikipedia.or...|
# |Minor punctuation...|  safe|  MuhannadDarwish|{{Fats}}
# A '''sat...|{{Fats}}
# A '''sat...| Saturated fat|//en.wikipedia.or...|
# |                    |unsafe|Pedroisthebest17!|{{Infobox person
# ...|{{Infobox person
# ...|  Adrián Uribe|//en.wikipedia.or...|
# +--------------------+------+-----------------+--------------------+--------------------+--------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# -Wari...|
# |---
#
# +++
#
# -Wari...|
# |---
#
# +++
#
# -Wari...|
# +--------------------+
#
# +--------------------+------+-----------------+--------------------+--------------------+--------------+--------------------+--------------------+----+
# |             comment| label|        name_user|            text_new|            text_old|    title_page|            url_page|                diff|pred|
# +--------------------+------+-----------------+--------------------+--------------------+--------------+--------------------+--------------------+----+
# |      →‎Origins:trim|  safe|         Eebahgum|{{EngvarB|date=Se...|{{EngvarB|date=Se...|Fulk FitzWarin|//en.wikipedia.or...|---
#
# +++
#
# -Wari...|safe|
# |Minor punctuation...|  safe|  MuhannadDarwish|{{Fats}}
# A '''sat...|{{Fats}}
# A '''sat...| Saturated fat|//en.wikipedia.or...|---
#
# +++
#
# -Wari...|safe|
# |                    |unsafe|Pedroisthebest17!|{{Infobox person
# ...|{{Infobox person
# ...|  Adrián Uribe|//en.wikipedia.or...|---
#
# +++
#
# -Wari...|safe|
# +--------------------+------+-----------------+--------------------+--------------------+--------------+--------------------+--------------------+----+
#
# ========= 2020-04-24 01:03:50 =========
# +--------------------+-----+---------------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|      name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+---------------+--------------------+--------------------+--------------------+--------------------+
# |      Better picture| safe|       Snowdawg|{{Infobox weapon
# ...|{{Infobox weapon
# ...|           73mm LRAC|//en.wikipedia.or...|
# |Adding localshort...| safe|   Red Director|{{short descripti...|{{Infobox footbal...|        Reece Deakin|//en.wikipedia.or...|
# |→‎See also:Capita...| safe|Cryptopocalypse|{{infobox biodata...|{{infobox biodata...|Bovine genome dat...|//en.wikipedia.or...|
# +--------------------+-----+---------------+--------------------+--------------------+--------------------+--------------------+
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# -|ima...|
# |---
#
# +++
#
# -|ima...|
# |---
#
# +++
#
# -|ima...|
# +--------------------+
#
# +--------------------+-----+---------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |             comment|label|      name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +--------------------+-----+---------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |      Better picture| safe|       Snowdawg|{{Infobox weapon
# ...|{{Infobox weapon
# ...|           73mm LRAC|//en.wikipedia.or...|---
#
# +++
#
# -|ima...|safe|
# |Adding localshort...| safe|   Red Director|{{short descripti...|{{Infobox footbal...|        Reece Deakin|//en.wikipedia.or...|---
#
# +++
#
# -|ima...|safe|
# |→‎See also:Capita...| safe|Cryptopocalypse|{{infobox biodata...|{{infobox biodata...|Bovine genome dat...|//en.wikipedia.or...|---
#
# +++
#
# -|ima...|safe|
# +--------------------+-----+---------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
#
# ========= 2020-04-24 01:04:00 =========
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|   name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
# |→‎History:Source ...| safe|   Manologue|[[File:Urine preg...|[[File:Urine preg...|      Pregnancy test|//en.wikipedia.or...|
# |minor language ch...| safe|     DocWock|{{Use dmy dates|d...|{{Use dmy dates|d...|         Benzonatate|//en.wikipedia.or...|
# |Adding localshort...| safe|Red Director|{{short descripti...|{{Infobox footbal...|Jack Nicholls (fo...|//en.wikipedia.or...|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# -Reco...|
# |---
#
# +++
#
# -Reco...|
# |---
#
# +++
#
# -Reco...|
# +--------------------+
#
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |             comment|label|   name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |→‎History:Source ...| safe|   Manologue|[[File:Urine preg...|[[File:Urine preg...|      Pregnancy test|//en.wikipedia.or...|---
#
# +++
#
# -Reco...|safe|
# |minor language ch...| safe|     DocWock|{{Use dmy dates|d...|{{Use dmy dates|d...|         Benzonatate|//en.wikipedia.or...|---
#
# +++
#
# -Reco...|safe|
# |Adding localshort...| safe|Red Director|{{short descripti...|{{Infobox footbal...|Jack Nicholls (fo...|//en.wikipedia.or...|---
#
# +++
#
# -Reco...|safe|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
#
# ========= 2020-04-24 01:04:10 =========
# +-----------------+------+-------------+--------------------+--------------------+--------------------+--------------------+
# |          comment| label|    name_user|            text_new|            text_old|          title_page|            url_page|
# +-----------------+------+-------------+--------------------+--------------------+--------------------+--------------------+
# |(→‎Personal Life)|unsafe|107.13.108.91|{{short descripti...|{{short descripti...|Greg Peterson (Am...|//en.wikipedia.or...|
# |                 |  safe|  Moilforgold|{{Infobox book
# | ...|{{Infobox book
# | ...|     De re metallica|//en.wikipedia.or...|
# +-----------------+------+-------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# +===P...|
# |---
#
# +++
#
# +===P...|
# +--------------------+
#
# +-----------------+------+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |          comment| label|    name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +-----------------+------+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |(→‎Personal Life)|unsafe|107.13.108.91|{{short descripti...|{{short descripti...|Greg Peterson (Am...|//en.wikipedia.or...|---
#
# +++
#
# +===P...|safe|
# |                 |  safe|  Moilforgold|{{Infobox book
# | ...|{{Infobox book
# | ...|     De re metallica|//en.wikipedia.or...|---
#
# +++
#
# +===P...|safe|
# +-----------------+------+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
#
# ========= 2020-04-24 01:04:20 =========
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|   name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
# |Adding localshort...| safe|Red Director|{{short descripti...|{{Use dmy dates|d...|Cecil Smith (foot...|//en.wikipedia.or...|
# |Adding localshort...| safe|Red Director|{{short descripti...|'''George Alfred ...|George Owen (foot...|//en.wikipedia.or...|
# |Adding localshort...| safe|Red Director|{{short descripti...|{{Use British Eng...|Malcolm Page (foo...|//en.wikipedia.or...|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# +{{sh...|
# |---
#
# +++
#
# +{{sh...|
# |---
#
# +++
#
# +{{sh...|
# +--------------------+
#
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |             comment|label|   name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |Adding localshort...| safe|Red Director|{{short descripti...|{{Use dmy dates|d...|Cecil Smith (foot...|//en.wikipedia.or...|---
#
# +++
#
# +{{sh...|safe|
# |Adding localshort...| safe|Red Director|{{short descripti...|'''George Alfred ...|George Owen (foot...|//en.wikipedia.or...|---
#
# +++
#
# +{{sh...|safe|
# |Adding localshort...| safe|Red Director|{{short descripti...|{{Use British Eng...|Malcolm Page (foo...|//en.wikipedia.or...|---
#
# +++
#
# +{{sh...|safe|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
#
# ========= 2020-04-24 01:04:30 =========
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|   name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
# |Addingshort descr...| safe|Red Director|{{short descripti...|{{use British Eng...|Lyn Thomas (footb...|//en.wikipedia.or...|
# |                    | safe|   Hhfjbaker|{{Infobox militar...|{{Infobox militar...|    Charles G. Gould|//en.wikipedia.or...|
# |      →‎May:Spelling| safe|     EdmundT|{{Use dmy dates|d...|{{Use dmy dates|d...|2020 in British t...|//en.wikipedia.or...|
# |Adding localshort...| safe|Red Director|{{short descripti...|{{Infobox footbal...|John Phillips (fo...|//en.wikipedia.or...|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# +{{sh...|
# |---
#
# +++
#
# +{{sh...|
# |---
#
# +++
#
# +{{sh...|
# |---
#
# +++
#
# +{{sh...|
# +--------------------+
#
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |             comment|label|   name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |Addingshort descr...| safe|Red Director|{{short descripti...|{{use British Eng...|Lyn Thomas (footb...|//en.wikipedia.or...|---
#
# +++
#
# +{{sh...|safe|
# |                    | safe|   Hhfjbaker|{{Infobox militar...|{{Infobox militar...|    Charles G. Gould|//en.wikipedia.or...|---
#
# +++
#
# +{{sh...|safe|
# |      →‎May:Spelling| safe|     EdmundT|{{Use dmy dates|d...|{{Use dmy dates|d...|2020 in British t...|//en.wikipedia.or...|---
#
# +++
#
# +{{sh...|safe|
# |Adding localshort...| safe|Red Director|{{short descripti...|{{Infobox footbal...|John Phillips (fo...|//en.wikipedia.or...|---
#
# +++
#
# +{{sh...|safe|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
#
# ========= 2020-04-24 01:04:40 =========
# +--------------------+------+--------------+--------------------+--------------------+------------------+--------------------+
# |             comment| label|     name_user|            text_new|            text_old|        title_page|            url_page|
# +--------------------+------+--------------+--------------------+--------------------+------------------+--------------------+
# |                    |  safe|   BubbaGrumpy|{{Distinguish|Lin...|{{Distinguish|Lin...| Lincoln, Nebraska|//en.wikipedia.or...|
# |      (not accurate)|unsafe|165.225.50.142|{{Use mdy dates|d...|{{Use mdy dates|d...|       PeaceHealth|//en.wikipedia.or...|
# |Adding localshort...|  safe|  Red Director|{{short descripti...|{{Infobox footbal...|Callum King-Harmes|//en.wikipedia.or...|
# +--------------------+------+--------------+--------------------+--------------------+------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# +* Ca...|
# |---
#
# +++
#
# +* Ca...|
# |---
#
# +++
#
# +* Ca...|
# +--------------------+
#
# +--------------------+------+--------------+--------------------+--------------------+------------------+--------------------+--------------------+----+
# |             comment| label|     name_user|            text_new|            text_old|        title_page|            url_page|                diff|pred|
# +--------------------+------+--------------+--------------------+--------------------+------------------+--------------------+--------------------+----+
# |                    |  safe|   BubbaGrumpy|{{Distinguish|Lin...|{{Distinguish|Lin...| Lincoln, Nebraska|//en.wikipedia.or...|---
#
# +++
#
# +* Ca...|safe|
# |      (not accurate)|unsafe|165.225.50.142|{{Use mdy dates|d...|{{Use mdy dates|d...|       PeaceHealth|//en.wikipedia.or...|---
#
# +++
#
# +* Ca...|safe|
# |Adding localshort...|  safe|  Red Director|{{short descripti...|{{Infobox footbal...|Callum King-Harmes|//en.wikipedia.or...|---
#
# +++
#
# +* Ca...|safe|
# +--------------------+------+--------------+--------------------+--------------------+------------------+--------------------+--------------------+----+
#
# ========= 2020-04-24 01:04:50 =========
# +--------------------+-----+------------+--------------------+--------------------+----------------+--------------------+
# |             comment|label|   name_user|            text_new|            text_old|      title_page|            url_page|
# +--------------------+-----+------------+--------------------+--------------------+----------------+--------------------+
# |Adding localshort...| safe|Red Director|{{short descripti...|{{Use dmy dates|d...|Llewellyn Gwynne|//en.wikipedia.or...|
# |    Added categories| safe|       Srbtx|'''Carol Stoudt''...|'''Carol Stoudt''...|    Carol Stoudt|//en.wikipedia.or...|
# +--------------------+-----+------------+--------------------+--------------------+----------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# +{{sh...|
# |---
#
# +++
#
# +{{sh...|
# +--------------------+
#
# +--------------------+-----+------------+--------------------+--------------------+----------------+--------------------+--------------------+----+
# |             comment|label|   name_user|            text_new|            text_old|      title_page|            url_page|                diff|pred|
# +--------------------+-----+------------+--------------------+--------------------+----------------+--------------------+--------------------+----+
# |Adding localshort...| safe|Red Director|{{short descripti...|{{Use dmy dates|d...|Llewellyn Gwynne|//en.wikipedia.or...|---
#
# +++
#
# +{{sh...|safe|
# |    Added categories| safe|       Srbtx|'''Carol Stoudt''...|'''Carol Stoudt''...|    Carol Stoudt|//en.wikipedia.or...|---
#
# +++
#
# +{{sh...|safe|
# +--------------------+-----+------------+--------------------+--------------------+----------------+--------------------+--------------------+----+
#
# ========= 2020-04-24 01:05:10 =========
# +--------------------+-----+---------------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|      name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+---------------+--------------------+--------------------+--------------------+--------------------+
# |    →‎Notable alumni| safe|        Wbm1058|{{Infobox School
# ...|{{Infobox School
# ...|Manuel Dominguez ...|//en.wikipedia.or...|
# |→‎See also:Capita...| safe|Cryptopocalypse|{{for|the drug wi...|{{for|the drug wi...|             Sterane|//en.wikipedia.or...|
# +--------------------+-----+---------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# -* [[...|
# |---
#
# +++
#
# -* [[...|
# +--------------------+
#
# +--------------------+-----+---------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |             comment|label|      name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +--------------------+-----+---------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |    →‎Notable alumni| safe|        Wbm1058|{{Infobox School
# ...|{{Infobox School
# ...|Manuel Dominguez ...|//en.wikipedia.or...|---
#
# +++
#
# -* [[...|safe|
# |→‎See also:Capita...| safe|Cryptopocalypse|{{for|the drug wi...|{{for|the drug wi...|             Sterane|//en.wikipedia.or...|---
#
# +++
#
# -* [[...|safe|
# +--------------------+-----+---------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
#
# ========= 2020-04-24 01:05:20 =========
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|    name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+
# |     Added citations| safe|Kingarthur581|{{unreferenced|da...|{{unreferenced|da...|            Garbalia|//en.wikipedia.or...|
# |Adding localshort...| safe| Red Director|{{short descripti...|{{Use dmy dates|d...|          Ron Powell|//en.wikipedia.or...|
# |Adding localshort...| safe| Red Director|{{short descripti...|{{Use dmy dates|d...|Frank Donovan (fo...|//en.wikipedia.or...|
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# -The ...|
# |---
#
# +++
#
# -The ...|
# |---
#
# +++
#
# -The ...|
# +--------------------+
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |             comment|label|    name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |     Added citations| safe|Kingarthur581|{{unreferenced|da...|{{unreferenced|da...|            Garbalia|//en.wikipedia.or...|---
#
# +++
#
# -The ...|safe|
# |Adding localshort...| safe| Red Director|{{short descripti...|{{Use dmy dates|d...|          Ron Powell|//en.wikipedia.or...|---
#
# +++
#
# -The ...|safe|
# |Adding localshort...| safe| Red Director|{{short descripti...|{{Use dmy dates|d...|Frank Donovan (fo...|//en.wikipedia.or...|---
#
# +++
#
# -The ...|safe|
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
#
# ========= 2020-04-24 01:05:30 =========
# +--------------------+------+------------------+--------------------+--------------------+--------------------+--------------------+
# |             comment| label|         name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+------+------------------+--------------------+--------------------+--------------------+--------------------+
# |                    |unsafe|Chickenpox12345789|{{redirect|Carrag...|{{redirect|Carrag...|     Jamie Carragher|//en.wikipedia.or...|
# |Adding localshort...|  safe|      Red Director|{{short descripti...|{{Use dmy dates|d...|Lee Phillips (foo...|//en.wikipedia.or...|
# |(Fixed location a...|unsafe|       LukeyBear11|{{pp-vandalism|sm...|{{pp-vandalism|sm...|      2020 NFL Draft|//en.wikipedia.or...|
# |move citation to ...|  safe|   MaxwellMolecule|{{distinguish|Mas...|{{distinguish|Mas...|    Mathieu function|//en.wikipedia.or...|
# +--------------------+------+------------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# +|yea...|
# |---
#
# +++
#
# +|yea...|
# |---
#
# +++
#
# +|yea...|
# |---
#
# +++
#
# +|yea...|
# +--------------------+
#
# +--------------------+------+------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |             comment| label|         name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +--------------------+------+------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |                    |unsafe|Chickenpox12345789|{{redirect|Carrag...|{{redirect|Carrag...|     Jamie Carragher|//en.wikipedia.or...|---
#
# +++
#
# +|yea...|safe|
# |Adding localshort...|  safe|      Red Director|{{short descripti...|{{Use dmy dates|d...|Lee Phillips (foo...|//en.wikipedia.or...|---
#
# +++
#
# +|yea...|safe|
# |(Fixed location a...|unsafe|       LukeyBear11|{{pp-vandalism|sm...|{{pp-vandalism|sm...|      2020 NFL Draft|//en.wikipedia.or...|---
#
# +++
#
# +|yea...|safe|
# |move citation to ...|  safe|   MaxwellMolecule|{{distinguish|Mas...|{{distinguish|Mas...|    Mathieu function|//en.wikipedia.or...|---
#
# +++
#
# +|yea...|safe|
# +--------------------+------+------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
#
# ========= 2020-04-24 01:05:40 =========
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|    name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+
# |Adding localshort...| safe| Red Director|{{short descripti...|{{Use dmy dates|d...|Ivor Jones (footb...|//en.wikipedia.or...|
# |Importing Wikidat...| safe|NASCARfan0548|{{short descripti...|{{Infobox rail li...|  U2 (Berlin U-Bahn)|//en.wikipedia.or...|
# |Adding localshort...| safe| Red Director|{{short descripti...|{{Infobox footbal...|Jamie Harris (foo...|//en.wikipedia.or...|
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# +{{sh...|
# |---
#
# +++
#
# +{{sh...|
# |---
#
# +++
#
# +{{sh...|
# +--------------------+
#
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |             comment|label|    name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |Adding localshort...| safe| Red Director|{{short descripti...|{{Use dmy dates|d...|Ivor Jones (footb...|//en.wikipedia.or...|---
#
# +++
#
# +{{sh...|safe|
# |Importing Wikidat...| safe|NASCARfan0548|{{short descripti...|{{Infobox rail li...|  U2 (Berlin U-Bahn)|//en.wikipedia.or...|---
#
# +++
#
# +{{sh...|safe|
# |Adding localshort...| safe| Red Director|{{short descripti...|{{Infobox footbal...|Jamie Harris (foo...|//en.wikipedia.or...|---
#
# +++
#
# +{{sh...|safe|
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
#
# ========= 2020-04-24 01:05:50 =========
# +--------------------+-----+---------------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|      name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+---------------+--------------------+--------------------+--------------------+--------------------+
# |         direct link| safe|    WhisperToMe|{{Infobox settlem...|{{Infobox settlem...| Media, Pennsylvania|//en.wikipedia.or...|
# |→‎See also:Capita...| safe|Cryptopocalypse|{{Unreferenced|da...|{{Unreferenced|da...|Closeness (mathem...|//en.wikipedia.or...|
# |        →‎References| safe|    KingSkyLord|{{distinguish|202...|{{distinguish|202...|2019 NCAA Divisio...|//en.wikipedia.or...|
# |→‎See also:Capita...| safe|Cryptopocalypse|{{Chembox
# | Verif...|{{Chembox
# | Verif...|      Uranyl formate|//en.wikipedia.or...|
# |                    | safe|    Cavan121012|{{Multiple issues...|{{Multiple issues...|2018 Cavan Senior...|//en.wikipedia.or...|
# +--------------------+-----+---------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# -Medi...|
# |---
#
# +++
#
# -Medi...|
# |---
#
# +++
#
# -Medi...|
# |---
#
# +++
#
# -Medi...|
# |---
#
# +++
#
# -Medi...|
# +--------------------+
#
# +--------------------+-----+---------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |             comment|label|      name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +--------------------+-----+---------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |         direct link| safe|    WhisperToMe|{{Infobox settlem...|{{Infobox settlem...| Media, Pennsylvania|//en.wikipedia.or...|---
#
# +++
#
# -Medi...|safe|
# |→‎See also:Capita...| safe|Cryptopocalypse|{{Unreferenced|da...|{{Unreferenced|da...|Closeness (mathem...|//en.wikipedia.or...|---
#
# +++
#
# -Medi...|safe|
# |        →‎References| safe|    KingSkyLord|{{distinguish|202...|{{distinguish|202...|2019 NCAA Divisio...|//en.wikipedia.or...|---
#
# +++
#
# -Medi...|safe|
# |→‎See also:Capita...| safe|Cryptopocalypse|{{Chembox
# | Verif...|{{Chembox
# | Verif...|      Uranyl formate|//en.wikipedia.or...|---
#
# +++
#
# -Medi...|safe|
# |                    | safe|    Cavan121012|{{Multiple issues...|{{Multiple issues...|2018 Cavan Senior...|//en.wikipedia.or...|---
#
# +++
#
# -Medi...|safe|
# +--------------------+-----+---------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# ========= 2020-04-24 01:06:00 =========
# +--------------------+-----+---------------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|      name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+---------------+--------------------+--------------------+--------------------+--------------------+
# |→‎Special Intelli...| safe|       Cjrother|{{Infobox militar...|{{Infobox militar...|Special Support a...|//en.wikipedia.or...|
# |→‎External links:...| safe|       Tinshome|{{About|the curre...|{{About|the curre...|Front Nacional de...|//en.wikipedia.or...|
# |       →‎Exhibitions| safe| Soydeaguadilla|{{More citations ...|{{More citations ...|     Daniela Rossell|//en.wikipedia.or...|
# |Added information...| safe|Doctor S Monkey|[[File:Matilda El...|[[File:Matilda El...|Matilda Ellen Bishop|//en.wikipedia.or...|
# +--------------------+-----+---------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# -The ...|
# |---
#
# +++
#
# -The ...|
# |---
#
# +++
#
# -The ...|
# |---
#
# +++
#
# -The ...|
# +--------------------+
#
# +--------------------+-----+---------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |             comment|label|      name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +--------------------+-----+---------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |→‎Special Intelli...| safe|       Cjrother|{{Infobox militar...|{{Infobox militar...|Special Support a...|//en.wikipedia.or...|---
#
# +++
#
# -The ...|safe|
# |→‎External links:...| safe|       Tinshome|{{About|the curre...|{{About|the curre...|Front Nacional de...|//en.wikipedia.or...|---
#
# +++
#
# -The ...|safe|
# |       →‎Exhibitions| safe| Soydeaguadilla|{{More citations ...|{{More citations ...|     Daniela Rossell|//en.wikipedia.or...|---
#
# +++
#
# -The ...|safe|
# |Added information...| safe|Doctor S Monkey|[[File:Matilda El...|[[File:Matilda El...|Matilda Ellen Bishop|//en.wikipedia.or...|---
#
# +++
#
# -The ...|safe|
# +--------------------+-----+---------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
#
# ========= 2020-04-24 01:06:10 =========
# +--------------------+-----+--------------------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|           name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+--------------------+--------------------+--------------------+--------------------+--------------------+
# |                    | safe|            Twinsday|{{about|the clay ...|{{about|the clay ...|              Sienna|//en.wikipedia.or...|
# |Adding localshort...| safe|        Red Director|{{short descripti...|{{Use dmy dates|d...|        Dudley Lewis|//en.wikipedia.or...|
# |disambiguation li...| safe|The Spirit of Ooh...|{{About|a neighbo...|{{About|a neighbo...|Washington Height...|//en.wikipedia.or...|
# +--------------------+-----+--------------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# -'''S...|
# |---
#
# +++
#
# -'''S...|
# |---
#
# +++
#
# -'''S...|
# +--------------------+
#
# +--------------------+-----+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |             comment|label|           name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +--------------------+-----+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |                    | safe|            Twinsday|{{about|the clay ...|{{about|the clay ...|              Sienna|//en.wikipedia.or...|---
#
# +++
#
# -'''S...|safe|
# |Adding localshort...| safe|        Red Director|{{short descripti...|{{Use dmy dates|d...|        Dudley Lewis|//en.wikipedia.or...|---
#
# +++
#
# -'''S...|safe|
# |disambiguation li...| safe|The Spirit of Ooh...|{{About|a neighbo...|{{About|a neighbo...|Washington Height...|//en.wikipedia.or...|---
#
# +++
#
# -'''S...|safe|
# +--------------------+-----+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
#
# ========= 2020-04-24 01:06:40 =========
# +--------------------+-----+------------+--------------------+--------------------+---------------+--------------------+
# |             comment|label|   name_user|            text_new|            text_old|     title_page|            url_page|
# +--------------------+-----+------------+--------------------+--------------------+---------------+--------------------+
# |Adding localshort...| safe|Red Director|{{short descripti...|{{Use dmy dates|d...|Steve Aizlewood|//en.wikipedia.or...|
# +--------------------+-----+------------+--------------------+--------------------+---------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# +{{sh...|
# +--------------------+
#
# +--------------------+-----+------------+--------------------+--------------------+---------------+--------------------+--------------------+----+
# |             comment|label|   name_user|            text_new|            text_old|     title_page|            url_page|                diff|pred|
# +--------------------+-----+------------+--------------------+--------------------+---------------+--------------------+--------------------+----+
# |Adding localshort...| safe|Red Director|{{short descripti...|{{Use dmy dates|d...|Steve Aizlewood|//en.wikipedia.or...|---
#
# +++
#
# +{{sh...|safe|
# +--------------------+-----+------------+--------------------+--------------------+---------------+--------------------+--------------------+----+
#
# ========= 2020-04-24 01:06:50 =========
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|    name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+
# |→‎Video Games:bra...| safe|PumpkinButter|{{Infobox person
# ...|{{Infobox person
# ...|Georg Stanford Brown|//en.wikipedia.or...|
# |→‎College career:...| safe|     1980fast|{{short descripti...|{{short descripti...|        O. J. Howard|//en.wikipedia.or...|
# |Adding localshort...| safe| Red Director|{{short descripti...|{{Use dmy dates|d...|Ian Evans (footba...|//en.wikipedia.or...|
# |→‎With Liberty N'...| safe|TheUnbeholden|{{short descripti...|{{short descripti...|           Lou Gramm|//en.wikipedia.or...|
# |Importing Wikidat...| safe|NASCARfan0548|{{short descripti...|{{distinguish|Tra...|    Street name sign|//en.wikipedia.or...|
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# -|''M...|
# |---
#
# +++
#
# -|''M...|
# |---
#
# +++
#
# -|''M...|
# |---
#
# +++
#
# -|''M...|
# |---
#
# +++
#
# -|''M...|
# +--------------------+
#
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |             comment|label|    name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |→‎Video Games:bra...| safe|PumpkinButter|{{Infobox person
# ...|{{Infobox person
# ...|Georg Stanford Brown|//en.wikipedia.or...|---
#
# +++
#
# -|''M...|safe|
# |→‎College career:...| safe|     1980fast|{{short descripti...|{{short descripti...|        O. J. Howard|//en.wikipedia.or...|---
#
# +++
#
# -|''M...|safe|
# |Adding localshort...| safe| Red Director|{{short descripti...|{{Use dmy dates|d...|Ian Evans (footba...|//en.wikipedia.or...|---
#
# +++
#
# -|''M...|safe|
# |→‎With Liberty N'...| safe|TheUnbeholden|{{short descripti...|{{short descripti...|           Lou Gramm|//en.wikipedia.or...|---
#
# +++
#
# -|''M...|safe|
# |Importing Wikidat...| safe|NASCARfan0548|{{short descripti...|{{distinguish|Tra...|    Street name sign|//en.wikipedia.or...|---
#
# +++
#
# -|''M...|safe|
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# ========= 2020-04-24 01:07:00 =========
# +--------------------+-----+---------------+--------------------+--------------------+-------------------+--------------------+
# |             comment|label|      name_user|            text_new|            text_old|         title_page|            url_page|
# +--------------------+-----+---------------+--------------------+--------------------+-------------------+--------------------+
# |    Added categories| safe|          Srbtx|Sigi Friedmann (b...|Sigi Friedmann (b...|     Sigi Friedmann|//en.wikipedia.or...|
# |→‎Unconfirmed iso...| safe|ComplexRational|{{infobox hassium...|{{infobox hassium...|Isotopes of hassium|//en.wikipedia.or...|
# |               →‎Art| safe| Soydeaguadilla|{{More citations ...|{{More citations ...|    Daniela Rossell|//en.wikipedia.or...|
# |               →‎top| safe|    KingSkyLord|{{short descripti...|{{short descripti...|       Adam Thielen|//en.wikipedia.or...|
# |    →‎External links| safe|        Moe1810|{{Infobox televis...|{{Infobox televis...|      Dead Husbands|//en.wikipedia.or...|
# +--------------------+-----+---------------+--------------------+--------------------+-------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# +<ref...|
# |---
#
# +++
#
# +<ref...|
# |---
#
# +++
#
# +<ref...|
# |---
#
# +++
#
# +<ref...|
# |---
#
# +++
#
# +<ref...|
# +--------------------+
#
# +--------------------+-----+---------------+--------------------+--------------------+-------------------+--------------------+--------------------+----+
# |             comment|label|      name_user|            text_new|            text_old|         title_page|            url_page|                diff|pred|
# +--------------------+-----+---------------+--------------------+--------------------+-------------------+--------------------+--------------------+----+
# |    Added categories| safe|          Srbtx|Sigi Friedmann (b...|Sigi Friedmann (b...|     Sigi Friedmann|//en.wikipedia.or...|---
#
# +++
#
# +<ref...|safe|
# |→‎Unconfirmed iso...| safe|ComplexRational|{{infobox hassium...|{{infobox hassium...|Isotopes of hassium|//en.wikipedia.or...|---
#
# +++
#
# +<ref...|safe|
# |               →‎Art| safe| Soydeaguadilla|{{More citations ...|{{More citations ...|    Daniela Rossell|//en.wikipedia.or...|---
#
# +++
#
# +<ref...|safe|
# |               →‎top| safe|    KingSkyLord|{{short descripti...|{{short descripti...|       Adam Thielen|//en.wikipedia.or...|---
#
# +++
#
# +<ref...|safe|
# |    →‎External links| safe|        Moe1810|{{Infobox televis...|{{Infobox televis...|      Dead Husbands|//en.wikipedia.or...|---
#
# +++
#
# +<ref...|safe|
# +--------------------+-----+---------------+--------------------+--------------------+-------------------+--------------------+--------------------+----+
#
# ========= 2020-04-24 01:07:10 =========

# %%
ssc_t.stop()
# Out:
# ----- Stopping... this may take a few seconds -----
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|    name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+
# |                    | safe|      Ythrych|#REDIRECT [[LGBT ...|#REDIRECT [[LGBT ...|LGBT history in B...|//en.wikipedia.or...|
# |→‎Collegiate care...| safe|     1980fast|{{short descripti...|{{short descripti...|        O. J. Howard|//en.wikipedia.or...|
# |→‎Accolades:CAPIT...| safe|    Fezzy1347|{{Short descripti...|{{Short descripti...|         Duma Ndlovu|//en.wikipedia.or...|
# |→‎Effects on huma...| safe|RockMagnetist|{{about|general a...|{{about|general a...|               Water|//en.wikipedia.or...|
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# +{{co...|
# |---
#
# +++
#
# +{{co...|
# |---
#
# +++
#
# +{{co...|
# |---
#
# +++
#
# +{{co...|
# +--------------------+
#
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |             comment|label|    name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |                    | safe|      Ythrych|#REDIRECT [[LGBT ...|#REDIRECT [[LGBT ...|LGBT history in B...|//en.wikipedia.or...|---
#
# +++
#
# +{{co...|safe|
# |→‎Collegiate care...| safe|     1980fast|{{short descripti...|{{short descripti...|        O. J. Howard|//en.wikipedia.or...|---
#
# +++
#
# +{{co...|safe|
# |→‎Accolades:CAPIT...| safe|    Fezzy1347|{{Short descripti...|{{Short descripti...|         Duma Ndlovu|//en.wikipedia.or...|---
#
# +++
#
# +{{co...|safe|
# |→‎Effects on huma...| safe|RockMagnetist|{{about|general a...|{{about|general a...|               Water|//en.wikipedia.or...|---
#
# +++
#
# +{{co...|safe|
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
#
# ========= 2020-04-24 01:07:20 =========
# +--------------------+------+----------+--------------------+--------------------+--------------------+--------------------+
# |             comment| label| name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+------+----------+--------------------+--------------------+--------------------+--------------------+
# |Changed grammatic...|  safe| Hollywooo|{{short descripti...|{{short descripti...|William Higgins (...|//en.wikipedia.or...|
# |                    |unsafe|2.27.60.20|{{Short descripti...|{{Short descripti...|      Olivia O'Brien|//en.wikipedia.or...|
# |            Fix typo|  safe|  Mandarax|{{distinguish|The...|{{distinguish|The...|    The Big Night In|//en.wikipedia.or...|
# |U.S. >> United St...|  safe|      Erik|{{Use mdy dates|d...|{{Use mdy dates|d...|      Lauren Ridloff|//en.wikipedia.or...|
# +--------------------+------+----------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# -'''W...|
# |---
#
# +++
#
# -'''W...|
# |---
#
# +++
#
# -'''W...|
# |---
#
# +++
#
# -'''W...|
# +--------------------+
#
# +--------------------+------+----------+--------------------+--------------------+--------------------+--------------------+--------------------+------+
# |             comment| label| name_user|            text_new|            text_old|          title_page|            url_page|                diff|  pred|
# +--------------------+------+----------+--------------------+--------------------+--------------------+--------------------+--------------------+------+
# |Changed grammatic...|  safe| Hollywooo|{{short descripti...|{{short descripti...|William Higgins (...|//en.wikipedia.or...|---
#
# +++
#
# -'''W...|vandal|
# |                    |unsafe|2.27.60.20|{{Short descripti...|{{Short descripti...|      Olivia O'Brien|//en.wikipedia.or...|---
#
# +++
#
# -'''W...|vandal|
# |            Fix typo|  safe|  Mandarax|{{distinguish|The...|{{distinguish|The...|    The Big Night In|//en.wikipedia.or...|---
#
# +++
#
# -'''W...|vandal|
# |U.S. >> United St...|  safe|      Erik|{{Use mdy dates|d...|{{Use mdy dates|d...|      Lauren Ridloff|//en.wikipedia.or...|---
#
# +++
#
# -'''W...|vandal|
# +--------------------+------+----------+--------------------+--------------------+--------------------+--------------------+--------------------+------+
#
# ========= 2020-04-24 01:07:50 =========
# +--------------------+------+--------------+--------------------+--------------------+--------------+--------------------+
# |             comment| label|     name_user|            text_new|            text_old|    title_page|            url_page|
# +--------------------+------+--------------+--------------------+--------------------+--------------+--------------------+
# |(Essential inform...|unsafe|200.118.156.23|{{Infobox philoso...|{{Infobox philoso...|Gonzalo Arango|//en.wikipedia.or...|
# +--------------------+------+--------------+--------------------+--------------------+--------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# -| sc...|
# +--------------------+
#
# +--------------------+------+--------------+--------------------+--------------------+--------------+--------------------+--------------------+----+
# |             comment| label|     name_user|            text_new|            text_old|    title_page|            url_page|                diff|pred|
# +--------------------+------+--------------+--------------------+--------------------+--------------+--------------------+--------------------+----+
# |(Essential inform...|unsafe|200.118.156.23|{{Infobox philoso...|{{Infobox philoso...|Gonzalo Arango|//en.wikipedia.or...|---
#
# +++
#
# -| sc...|safe|
# +--------------------+------+--------------+--------------------+--------------------+--------------+--------------------+--------------------+----+
#
# ========= 2020-04-24 01:08:00 =========
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|    name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+
# |        →‎References| safe|Adroit.bakhat|{{short descripti...|{{short descripti...|Bigg Boss (Hindi ...|//en.wikipedia.or...|
# |Replaced "breed" ...| safe|    Grwedits2|{{refimprove|date...|{{refimprove|date...|         Rat Terrier|//en.wikipedia.or...|
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# -{{Re...|
# |---
#
# +++
#
# -{{Re...|
# +--------------------+
#
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |             comment|label|    name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |        →‎References| safe|Adroit.bakhat|{{short descripti...|{{short descripti...|Bigg Boss (Hindi ...|//en.wikipedia.or...|---
#
# +++
#
# -{{Re...|safe|
# |Replaced "breed" ...| safe|    Grwedits2|{{refimprove|date...|{{refimprove|date...|         Rat Terrier|//en.wikipedia.or...|---
#
# +++
#
# -{{Re...|safe|
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# ========= 2020-04-24 01:08:10 =========
# +--------------------+-----+-----------------+--------------------+--------------------+----------------+--------------------+
# |             comment|label|        name_user|            text_new|            text_old|      title_page|            url_page|
# +--------------------+-----+-----------------+--------------------+--------------------+----------------+--------------------+
# |      improved prose| safe|         Vmavanti|{{Infobox musical...|{{Infobox musical...|    Ulf Wakenius|//en.wikipedia.or...|
# |     Added citations| safe|    Kingarthur581|{{unreferenced|da...|{{unreferenced|da...|        Garbalia|//en.wikipedia.or...|
# |Added sentence ab...| safe|Osu.archivist.tem|{{good article}}
# ...|{{good article}}
# ...|Women in brewing|//en.wikipedia.or...|
# |→‎Early life and ...| safe|     Urbanguru182|{{Lead too short|...|{{Lead too short|...|     Mike Albert|//en.wikipedia.or...|
# +--------------------+-----+-----------------+--------------------+--------------------+----------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# -| im...|
# |---
#
# +++
#
# -| im...|
# |---
#
# +++
#
# -| im...|
# |---
#
# +++
#
# -| im...|
# +--------------------+
#
# +--------------------+-----+-----------------+--------------------+--------------------+----------------+--------------------+--------------------+----+
# |             comment|label|        name_user|            text_new|            text_old|      title_page|            url_page|                diff|pred|
# +--------------------+-----+-----------------+--------------------+--------------------+----------------+--------------------+--------------------+----+
# |      improved prose| safe|         Vmavanti|{{Infobox musical...|{{Infobox musical...|    Ulf Wakenius|//en.wikipedia.or...|---
#
# +++
#
# -| im...|safe|
# |     Added citations| safe|    Kingarthur581|{{unreferenced|da...|{{unreferenced|da...|        Garbalia|//en.wikipedia.or...|---
#
# +++
#
# -| im...|safe|
# |Added sentence ab...| safe|Osu.archivist.tem|{{good article}}
# ...|{{good article}}
# ...|Women in brewing|//en.wikipedia.or...|---
#
# +++
#
# -| im...|safe|
# |→‎Early life and ...| safe|     Urbanguru182|{{Lead too short|...|{{Lead too short|...|     Mike Albert|//en.wikipedia.or...|---
#
# +++
#
# -| im...|safe|
# +--------------------+-----+-----------------+--------------------+--------------------+----------------+--------------------+--------------------+----+
#
# ========= 2020-04-24 01:08:20 =========
# +----------------+------+--------------+--------------------+--------------------+------------------+--------------------+
# |         comment| label|     name_user|            text_new|            text_old|        title_page|            url_page|
# +----------------+------+--------------+--------------------+--------------------+------------------+--------------------+
# |  Notable person|  safe|   BubbaGrumpy|{{short descripti...|{{short descripti...|Morton, Washington|//en.wikipedia.or...|
# |→‎External links|  safe|West Virginian|{{short descripti...|{{short descripti...|Ethel McGhee Davis|//en.wikipedia.or...|
# |    (Fixed typo)|unsafe|     Indracoop|{{wiktionary|EMIL...|{{wiktionary|EMIL...|             Emily|//en.wikipedia.or...|
# +----------------+------+--------------+--------------------+--------------------+------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# +*Meg...|
# |---
#
# +++
#
# +*Meg...|
# |---
#
# +++
#
# +*Meg...|
# +--------------------+
#
# +----------------+------+--------------+--------------------+--------------------+------------------+--------------------+--------------------+----+
# |         comment| label|     name_user|            text_new|            text_old|        title_page|            url_page|                diff|pred|
# +----------------+------+--------------+--------------------+--------------------+------------------+--------------------+--------------------+----+
# |  Notable person|  safe|   BubbaGrumpy|{{short descripti...|{{short descripti...|Morton, Washington|//en.wikipedia.or...|---
#
# +++
#
# +*Meg...|safe|
# |→‎External links|  safe|West Virginian|{{short descripti...|{{short descripti...|Ethel McGhee Davis|//en.wikipedia.or...|---
#
# +++
#
# +*Meg...|safe|
# |    (Fixed typo)|unsafe|     Indracoop|{{wiktionary|EMIL...|{{wiktionary|EMIL...|             Emily|//en.wikipedia.or...|---
#
# +++
#
# +*Meg...|safe|
# +----------------+------+--------------+--------------------+--------------------+------------------+--------------------+--------------------+----+
#
# ========= 2020-04-24 01:08:30 =========
# +--------------------+-----+-----------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|  name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+-----------+--------------------+--------------------+--------------------+--------------------+
# |remove unnecessar...| safe|Senator2029|[[File:Renewables...|[[File:Renewables...|The Renewables In...|//en.wikipedia.or...|
# |→‎World War I:fix...| safe|     Choess|{{other ships|Rus...|{{other ships|Rus...|Russian cruiser R...|//en.wikipedia.or...|
# |        Correct term| safe|   Mandarax|{{Use dmy dates|d...|{{Use dmy dates|d...|Basavraj Madhavra...|//en.wikipedia.or...|
# +--------------------+-----+-----------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# -'''T...|
# |---
#
# +++
#
# -'''T...|
# |---
#
# +++
#
# -'''T...|
# +--------------------+
#
# +--------------------+-----+-----------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |             comment|label|  name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +--------------------+-----+-----------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |remove unnecessar...| safe|Senator2029|[[File:Renewables...|[[File:Renewables...|The Renewables In...|//en.wikipedia.or...|---
#
# +++
#
# -'''T...|safe|
# |→‎World War I:fix...| safe|     Choess|{{other ships|Rus...|{{other ships|Rus...|Russian cruiser R...|//en.wikipedia.or...|---
#
# +++
#
# -'''T...|safe|
# |        Correct term| safe|   Mandarax|{{Use dmy dates|d...|{{Use dmy dates|d...|Basavraj Madhavra...|//en.wikipedia.or...|---
#
# +++
#
# -'''T...|safe|
# +--------------------+-----+-----------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
#
# ========= 2020-04-24 01:08:40 =========
# +--------------+------+------------+--------------------+--------------------+-------------------+--------------------+
# |       comment| label|   name_user|            text_new|            text_old|         title_page|            url_page|
# +--------------+------+------------+--------------------+--------------------+-------------------+--------------------+
# |     (Website)|unsafe|223.189.97.8|{{Multiple issues...|{{Multiple issues...|  Muhammad Jaunpuri|//en.wikipedia.or...|
# |rm extra space|  safe|    M.nelson|{{short descripti...|{{short descripti...|Guinness Storehouse|//en.wikipedia.or...|
# |              |unsafe|45.50.54.160|{{Infobox rail
# | ...|{{Infobox rail
# | ...|              RFFSA|//en.wikipedia.or...|
# |              |unsafe|45.50.54.160|{{about||the 1998...|{{about||the 1998...|  Central do Brasil|//en.wikipedia.or...|
# +--------------+------+------------+--------------------+--------------------+-------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# -'''H...|
# |---
#
# +++
#
# -'''H...|
# |---
#
# +++
#
# -'''H...|
# |---
#
# +++
#
# -'''H...|
# +--------------------+
#
# +--------------+------+------------+--------------------+--------------------+-------------------+--------------------+--------------------+------+
# |       comment| label|   name_user|            text_new|            text_old|         title_page|            url_page|                diff|  pred|
# +--------------+------+------------+--------------------+--------------------+-------------------+--------------------+--------------------+------+
# |     (Website)|unsafe|223.189.97.8|{{Multiple issues...|{{Multiple issues...|  Muhammad Jaunpuri|//en.wikipedia.or...|---
#
# +++
#
# -'''H...|vandal|
# |rm extra space|  safe|    M.nelson|{{short descripti...|{{short descripti...|Guinness Storehouse|//en.wikipedia.or...|---
#
# +++
#
# -'''H...|vandal|
# |              |unsafe|45.50.54.160|{{Infobox rail
# | ...|{{Infobox rail
# | ...|              RFFSA|//en.wikipedia.or...|---
#
# +++
#
# -'''H...|vandal|
# |              |unsafe|45.50.54.160|{{about||the 1998...|{{about||the 1998...|  Central do Brasil|//en.wikipedia.or...|---
#
# +++
#
# -'''H...|vandal|
# +--------------+------+------------+--------------------+--------------------+-------------------+--------------------+--------------------+------+
# ========= 2020-04-24 01:08:50 =========
# +--------------------+-----+---------+--------------------+--------------------+------------+--------------------+
# |             comment|label|name_user|            text_new|            text_old|  title_page|            url_page|
# +--------------------+-----+---------+--------------------+--------------------+------------+--------------------+
# |→‎Collegiate care...| safe| 1980fast|{{short descripti...|{{short descripti...|O. J. Howard|//en.wikipedia.or...|
# +--------------------+-----+---------+--------------------+--------------------+------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# -As a...|
# +--------------------+
#
# +--------------------+-----+---------+--------------------+--------------------+------------+--------------------+--------------------+----+
# |             comment|label|name_user|            text_new|            text_old|  title_page|            url_page|                diff|pred|
# +--------------------+-----+---------+--------------------+--------------------+------------+--------------------+--------------------+----+
# |→‎Collegiate care...| safe| 1980fast|{{short descripti...|{{short descripti...|O. J. Howard|//en.wikipedia.or...|---
#
# +++
#
# -As a...|safe|
# +--------------------+-----+---------+--------------------+--------------------+------------+--------------------+--------------------+----+
#
# ========= 2020-04-24 01:09:20 =========
# +-------+-----+---------+--------------------+--------------------+----------+--------------------+
# |comment|label|name_user|            text_new|            text_old|title_page|            url_page|
# +-------+-----+---------+--------------------+--------------------+----------+--------------------+
# |       | safe| Godaiger|{{multiple issues...|{{multiple issues...|  Amr Diab|//en.wikipedia.or...|
# +-------+-----+---------+--------------------+--------------------+----------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# -Acco...|
# +--------------------+
#
# +-------+-----+---------+--------------------+--------------------+----------+--------------------+--------------------+----+
# |comment|label|name_user|            text_new|            text_old|title_page|            url_page|                diff|pred|
# +-------+-----+---------+--------------------+--------------------+----------+--------------------+--------------------+----+
# |       | safe| Godaiger|{{multiple issues...|{{multiple issues...|  Amr Diab|//en.wikipedia.or...|---
#
# +++
#
# -Acco...|safe|
# +-------+-----+---------+--------------------+--------------------+----------+--------------------+--------------------+----+
